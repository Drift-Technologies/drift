#   'longitude': -123.17131805419922,
#   'current_stop_sequence': 1,
#   'current_status': 2,
#   'timestamp': 1740178368,
#   'stop_id': '55',
#   'current_datetime': '2025-02-21T22:53:48.581660+00:00',
#   'h3_7': '8728de8ceffffff'},
#  {'id': '14256845',
# ...

# %%
import folium
from statistics import mean

def create_vehicle_map(data):
    # Calculate the center of the map using the mean of all coordinates
    lats = [d['latitude'] for d in data]
    lons = [d['longitude'] for d in data]
    center_lat = mean(lats)
    center_lon = mean(lons)
    
    # Create a map centered on the mean position
    m = folium.Map(location=[center_lat, center_lon], 
                  zoom_start=13,
                  tiles='OpenStreetMap')
    
    # Add markers for each vehicle
    for vehicle in data:
        # Create popup text with relevant information
        popup_text = f"""
        Route: {vehicle['route_id']}
        Vehicle: {vehicle['vehicle_label']}
        Direction: {vehicle['direction_id']}
        Stop ID: {vehicle['stop_id']}
        """
        
        # Add marker to map
        folium.CircleMarker(
            location=[vehicle['latitude'], vehicle['longitude']],
            radius=5,
            popup=popup_text,
            color='blue',
            fill=True,
            fill_color='blue'
        ).add_to(m)
    
    return m

# Create the map
vehicle_map = create_vehicle_map(temp_data['data'])

# %%
vehicle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import h3

# %%
# Get the center h3 index
center_h3 = h3.geo_to_h3(49.25330435585066, -123.18454924698467, 7)

# Get k-ring hexagons
h3_kring_list = list(h3.k_ring(center_h3, 1))

# Get center coordinates
center_lat, center_lng = h3.h3_to_geo(center_h3)

# Calculate distances for each hexagon in k-ring
distances = []
for hex_id in h3_kring_list:
    # Convert hex to lat/lng
    hex_lat, hex_lng = h3.h3_to_geo(hex_id)
    
    # Calculate distance from center
    dist = h3.point_dist(
        (center_lat, center_lng),
        (hex_lat, hex_lng),
        unit='km'
    )
    
    distances.append({
        'hex_id': hex_id,
        'lat': hex_lat,
        'lng': hex_lng,
        'distance_km': dist
    })

# Display results
distances
# Out:
# [{'hex_id': '8728de8caffffff',
#   'lat': 49.28237378936511,
#   'lng': -123.18110060858189,
#   'distance_km': 2.162719854492976},
#  {'hex_id': '8728de8c3ffffff',
#   'lat': 49.25589666111574,
#   'lng': -123.15101299367842,
#   'distance_km': 2.206463802906603},
#  {'hex_id': '8728de8c1ffffff',
#   'lat': 49.243529307900666,
#   'lng': -123.17775900984668,
#   'distance_km': 2.163395263981808},
#  {'hex_id': '8728de8ceffffff',
#   'lat': 49.26295459295264,
#   'lng': -123.17942941245934,
#   'distance_km': 0.0},
#  {'hex_id': '8728de8c8ffffff',
#   'lat': 49.270003574135956,
#   'lng': -123.2078459706763,
#   'distance_km': 2.205843946549517},
#  {'hex_id': '8728de8ccffffff',
#   'lat': 49.2505825294973,
#   'lng': -123.20616881802545,
#   'distance_km': 2.3787445756382946},
#  {'hex_id': '8728de8ddffffff',
#   'lat': 49.275320096041426,
#   'lng': -123.15267743584664,
#   'distance_km': 2.378670168208229}]

# %%
h3.hex_range_distances('8728de8ceffffff', 1)
# Out:
# [{'8728de8ceffffff'},
#  {'8728de8c1ffffff',
#   '8728de8c3ffffff',
#   '8728de8c8ffffff',
#   '8728de8caffffff',
#   '8728de8ccffffff',
#   '8728de8ddffffff'}]
